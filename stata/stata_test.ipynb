# %% [markdown]
# # Stata 19 on Verily Workbench
#
# Before running this notebook, run the setup script once per app session:
#
# ```bash
# bash ~/repos/workbench-examples/stata/setup_pystata.sh
# ```

# %%
import stata_setup
stata_setup.config("/home/jupyter/workspace/uploads/stata/stata19", "mp")

# %%
from pystata import stata

stata.run("sysuse auto, clear")
stata.run("describe")

# %%
stata.run("summarize price mpg weight")
